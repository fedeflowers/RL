# %% [markdown]
# # Pendulum_v0

# %%
import gym
import random
import numpy as np
import os

# %%
env = gym.make('Pendulum-v0')
obs = env.observation_space.shape[0]
actions = env.action_space   #actions are continuos

# %%
type(actions)
# Out:
# gym.spaces.discrete.Discrete

# %%
episodes = 5
for episode in range(1, episodes+1):
    obv = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        obv, reward, done, info = env.step(action)
        score += reward
    print('Episode{} , Score{}'.format(episode,score))
env.close()
# Out:
# Episode1 , Score-200.0
# Episode2 , Score-200.0
# Episode3 , Score-200.0
# Episode4 , Score-200.0
# Episode5 , Score-200.0

# %% [markdown]
# # Build Agent

# %%
from stable_baselines3 import DDPG
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env = DummyVecEnv([lambda:env]) #vetorized enviroment
model = DDPG('MlpPolicy', env, verbose=1)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=50000)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 756  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005463831 |
# |    clip_fraction        | 0.00454     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.773      |
# |    explained_variance   | 0.036       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 94.2        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.000379    |
# |    value_loss           | 160         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 536         |
# |    iterations           | 3           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.001743526 |
# |    clip_fraction        | 0.012       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.717      |
# |    explained_variance   | 0.0442      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000235   |
# |    value_loss           | 164         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 509           |
# |    iterations           | 4             |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00085023564 |
# |    clip_fraction        | 0.00645       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.753        |
# |    explained_variance   | 0.0333        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 121           |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000212     |
# |    value_loss           | 167           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 499           |
# |    iterations           | 5             |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00022187686 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.697        |
# |    explained_variance   | 0.0811        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 38.4          |
# |    n_updates            | 190           |
# |    policy_gradient_loss | 0.000114      |
# |    value_loss           | 162           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 496         |
# |    iterations           | 6           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007829303 |
# |    clip_fraction        | 0.0445      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | 0.0406      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00104    |
# |    value_loss           | 181         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 491           |
# |    iterations           | 7             |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.00060414895 |
# |    clip_fraction        | 0.0119        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.661        |
# |    explained_variance   | 0.0487        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 71.3          |
# |    n_updates            | 210           |
# |    policy_gradient_loss | 0.00021       |
# |    value_loss           | 168           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 8            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0064168274 |
# |    clip_fraction        | 0.0718       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.572       |
# |    explained_variance   | 0.0793       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87.2         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00282     |
# |    value_loss           | 166          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 481          |
# |    iterations           | 9            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0034393317 |
# |    clip_fraction        | 0.0554       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.497       |
# |    explained_variance   | 0.103        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 82.4         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00264     |
# |    value_loss           | 171          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 480          |
# |    iterations           | 10           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0017744069 |
# |    clip_fraction        | 0.0199       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.448       |
# |    explained_variance   | 0.103        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 94.8         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 173          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 11           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0023183047 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.394       |
# |    explained_variance   | 0.0672       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.2         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000667    |
# |    value_loss           | 166          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 484          |
# |    iterations           | 12           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0024119564 |
# |    clip_fraction        | 0.00806      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.375       |
# |    explained_variance   | 0.167        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 73.7         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 0.000567     |
# |    value_loss           | 158          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 486          |
# |    iterations           | 13           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0013948397 |
# |    clip_fraction        | 0.00977      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.326       |
# |    explained_variance   | 0.138        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.9         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000309    |
# |    value_loss           | 162          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 488           |
# |    iterations           | 14            |
# |    time_elapsed         | 58            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 2.6092603e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.291        |
# |    explained_variance   | 0.0979        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 125           |
# |    n_updates            | 280           |
# |    policy_gradient_loss | 0.000278      |
# |    value_loss           | 182           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 489         |
# |    iterations           | 15          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.001707752 |
# |    clip_fraction        | 0.0123      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.288      |
# |    explained_variance   | 0.102       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.2        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.000649   |
# |    value_loss           | 163         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 490          |
# |    iterations           | 16           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0014175918 |
# |    clip_fraction        | 0.0302       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.266       |
# |    explained_variance   | 0.0668       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 82.3         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 170          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 488        |
# |    iterations           | 17         |
# |    time_elapsed         | 71         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00391539 |
# |    clip_fraction        | 0.0106     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.256     |
# |    explained_variance   | 0.116      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 88.2       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 6.04e-05   |
# |    value_loss           | 164        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 489         |
# |    iterations           | 18          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.000876648 |
# |    clip_fraction        | 0.00396     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.295      |
# |    explained_variance   | 0.0919      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.8        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.000637   |
# |    value_loss           | 176         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 490          |
# |    iterations           | 19           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0013931917 |
# |    clip_fraction        | 0.0245       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.304       |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 141          |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 167          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 491          |
# |    iterations           | 20           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0012098264 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.28        |
# |    explained_variance   | 0.219        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.3         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000983    |
# |    value_loss           | 164          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 492          |
# |    iterations           | 21           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0017307095 |
# |    clip_fraction        | 0.0149       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.239       |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 103          |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000898    |
# |    value_loss           | 162          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 493           |
# |    iterations           | 22            |
# |    time_elapsed         | 91            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00068149285 |
# |    clip_fraction        | 0.00649       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.202        |
# |    explained_variance   | 0.173         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 83.6          |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.00058      |
# |    value_loss           | 166           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 489          |
# |    iterations           | 23           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0006388073 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.212       |
# |    explained_variance   | 0.146        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.2         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 7.39e-06     |
# |    value_loss           | 165          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 488          |
# |    iterations           | 24           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0016499902 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.178       |
# |    explained_variance   | 0.145        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 97           |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00071     |
# |    value_loss           | 163          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 25           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0015958339 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.162       |
# |    explained_variance   | 0.185        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 99.1         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000901    |
# |    value_loss           | 165          |
# ------------------------------------------

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# (-1025.0322613377125, 193.18529345112776)

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0
    
    while not done: 
        env.render()
        action, _ = model.predict(obs) #using model prediction
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()

# %%
env.close()
